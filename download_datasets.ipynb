# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nolasthitnotomorrow/radioml2016-deepsigcom")

print("Path to dataset files:", path)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("marwanabudeeb/rml201610b")

print("Path to dataset files:", path)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pinxau1000/radioml2018")

print("Path to dataset files:", path)

# %%
from matplotlib import pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(8, 4))

ax.grid("--", color="gray", alpha=0.4)

ax.plot(np.random.rand(128), color="royalblue", label="Train Loss")
ax.plot(np.random.rand(128), color="darkorange", label="Val Loss")

ax.legend(loc="upper right", fontsize=10.5)
ax.set_xlabel("Epochs", fontsize=12)
ax.set_ylabel("Classification Loss", fontsize=12)
# Out:
# Text(0, 0.5, 'Classification Loss')

# %%
fig, ax = plt.subplots(figsize=(10, 10))

from seaborn import heatmap

confusion = heatmap(
    np.random.rand(10, 10) * 100,
    square=True,
    annot=True,
    fmt="d",
    cmap="Blues",
    cbar=False,
    ax=ax,
    vmin=0,
    linecolor="k",
    linewidths=0.4,
    annot_kws={"size": 10},
    xticklabels=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"],
    yticklabels=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"],
)
cbar = confusion.figure.colorbar(
    confusion.collections[0], ax=confusion, location="right", shrink=0.8
)
ax.set_xlabel("Predicted label", fontsize=13)
ax.set_ylabel("True label", fontsize=13)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       1 fig, ax = plt.subplots(figsize=(10, 10))
#       3 from seaborn import heatmap
# ----> 5 confusion = heatmap(
#       6     np.random.rand(10, 10) * 100,
#       7     square=True,
#       8     annot=True,
#       9     fmt="d",
#      10     cmap="Blues",
#      11     cbar=False,
#      12     ax=ax,
#      13     vmin=0,
#      14     linecolor="k",
#      15     linewidths=0.4,
#      16     annot_kws={"size": 10},
#      17     xticklabels=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"],
#      18     yticklabels=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"],
#      19 )
#      20 cbar = confusion.figure.colorbar(
#      21     confusion.collections[0], ax=confusion, location="right", shrink=0.8
#      22 )
#      23 ax.set_xlabel("Predicted label", fontsize=13)
#
# File ~/anaconda3/envs/wwx_amc/lib/python3.11/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~/anaconda3/envs/wwx_amc/lib/python3.11/site-packages/seaborn/matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File ~/anaconda3/envs/wwx_amc/lib/python3.11/site-packages/seaborn/matrix.py:260, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     258 lum = relative_luminance(color)
#     259 text_color = ".15" if lum > .408 else "w"
# --> 260 annotation = ("{:" + self.fmt + "}").format(val)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'
